# %%
#Ex. 1
def f(x):
    return x**2 - 0.25*x + 5

x = 2.3
result = f(x)

print(result)
if result == 0:
    print('yes! f(x) = 0')
else:
    print('No! f(x) != 0')
# Out:
# 9.715
# No! f(x) != 0

# %%
# Ex. 2
import math

#x = math.pi/2 # 90 degree
#x = math.pi/3 # 60 degree
#x = math.pi/4 # 45 degree
#x = math.pi/6 # 30 degree

l = [math.pi/2, math.pi/3, math.pi/4, math.pi/6]
n = 2

print('Testing the moivre formula with many angles: 90, 60, 45 and 30 degrees')

for x in l:
    lS = (math.cos(x) + 1j * math.sin(x)) ** n
    rS = math.cos(n * x) + 1j * math.sin(n * x)
    
    if lS == rS:
        print('Yes! The formula is correct: {} = {}'.format(lS, rS))
    else:
        print('No! The formula is not correct: {} != {}'.format(lS, rS))
# Out:
# [1.5707963267948966, 1.0471975511965976, 0.7853981633974483, 0.5235987755982988]
# Testing the moivre formula with many angles: 90, 60, 45 and 30 degrees
# Yes! The formula is correct: (-1+1.2246467991473532e-16j) = (-1+1.2246467991473532e-16j)
# No! The formula is not correct: (-0.4999999999999998+0.8660254037844388j) != (-0.4999999999999998+0.8660254037844387j)
# No! The formula is not correct: 1.0000000000000002j != (6.123233995736766e-17+1j)
# No! The formula is not correct: (0.5000000000000002+0.8660254037844386j) != (0.5000000000000001+0.8660254037844386j)

# %%
#Ex 3
import math
import cmath

l = [math.pi/2, math.pi/3, math.pi/4, math.pi/6]

print('Testing the moivre formula with many angles: 90, 60, 45 and 30 degrees')
for x in l:
    lS = cmath.exp(1j * x)
    rS = math.cos(x) + 1j * math.sin(x)
    
    if lS == rS:
        print('Yes! The formula is correct: {} = {}'.format(lS, rS))
    else:
        print('No! The formula is not correct: {} != {}'.format(lS, rS))
# Out:
# Testing the moivre formula with many angles: 90, 60, 45 and 30 degrees
# Yes! The formula is correct: (6.123233995736766e-17+1j) = (6.123233995736766e-17+1j)
# Yes! The formula is correct: (0.5000000000000001+0.8660254037844386j) = (0.5000000000000001+0.8660254037844386j)
# Yes! The formula is correct: (0.7071067811865476+0.7071067811865476j) = (0.7071067811865476+0.7071067811865476j)
# Yes! The formula is correct: (0.8660254037844387+0.49999999999999994j) = (0.8660254037844387+0.49999999999999994j)

# %%
#Ex. 4
u = 1.0  # you have to use a float here!
uold = 10.  
for iteration in range(2000):
    if not abs(u - uold) > 1.e-8:
        print('Convergence')
        break # sequence has converged
    uold = u
    u = 2 * u
else:
    print('No convergence')
# Out:
# Convergence

# %%
'''1. Non i get the message 'Convergence' so the line the sequence has converged'''
# Out:
# "1. Non i get the message 'Convergence' so the line the sequence has converged"

# %%
u = 1.0  # you have to use a float here!
uold = 10.  
for iteration in range(2000):
    if abs(u - uold) < 1.e-8:
        print('Convergence')
        break # sequence has converged
    uold = u
    u = 2 * u
else:
    print('No convergence')
# Out:
# No convergence

# %%
'''2. It returns the message 'No convergence' is different '''
# Out:
# "2. It returns the message 'No convergence' is different "

# %%
u = 1  # you have to use a float here!
uold = 10.  
for iteration in range(2000):
    if not abs(u - uold) > 1.e-8:
        print('Convergence')
        break # sequence has converged
    uold = u
    u = 2 * u
else:
    print('No convergence')
# Out:
# No convergence

# %%
''' 3. i get the message 'No Convergence'''
# Out:
# " 3. i get the message 'No Convergence"

# %%
u = 1  # you have to use a float here!
uold = 10.  
for iteration in range(2000):
    if abs(u - uold) < 1.e-8:
        print('Convergence')
        break # sequence has converged
    uold = u
    u = 2 * u
else:
    print('No convergence')
# Out:
# No convergence

# %%
''' it is the same reesult.'''
# Out:
# ' it is the same reesult.'

# %%
''' 4. Here they are 4 case:
The 1st case: 
The script calculats the difrent between the current number and its 
previous and check if the not abs of this result > 10^(-8) and the suit gets 
bigger with every iterations so it will always be bigger that 10^(-8) so like 
this the condition will be always false it will be an infinity so we will get 
convergence. However when the number becone too big they turn into infinity and 
inf - inf = Nan, so here Nan < 10^(-8) will be false and not false equals to true 
so the Convergence message appears.


The 2nd case: 
The script calculates the difference between the current number and its previous 
and checks if the abs of this result < 10^(-8). The sequence gets bigger with 
every iteration so it will always be bigger than 10^(-8), so the condition will 
always be false. Even when the numbers become too big and turn into infinity, 
and inf - inf = NaN, here NaN < 10^(-8) will be false, so the condition stays 
false and we correctly get "No convergence" message.

The 3rd case:
The script uses integers instead of floats and calculates the difference between 
the current number and its previous, checking if not abs of this result > 10^(-8). 
With integers, the numbers can grow very large without turning into infinity, so 
the difference between terms is always at least 1, which is much bigger than 
10^(-8). So the condition abs(u - uold) > 1e-8 is always true, and not true is 
always false. Therefore, the condition stays false and we correctly get 
"No convergence" message.

The 4th case:
The script uses integers and calculates the difference between the current number 
and its previous, checking if abs of this result < 10^(-8). With integers, 
the numbers grow large without overflow problems, so the difference between 
terms is always at least 1, which is much bigger than 10^(-8). So the condition 
abs(u - uold) < 1e-8 is always false. Therefore, the condition stays false and 
we correctly get "No convergence" message.
'''
# Out:
# ' 4. Here they are 4 case:\nThe 1st case: \nThe script calculats the difrent between the current number and its \nprevious and check if the not abs of this result > 10^(-8) and the suit gets \nbigger with every iterations so it will always be bigger that 10^(-8) so like \nthis the condition will be always false it will be an infinity so we will get \nconvergence. However when the number becone too big they turn into infinity and \ninf - inf = Nan, so here Nan < 10^(-8) will be false and not false equals to true \nso the Convergence message appears.\n\n\nThe 2nd case: \nThe script calculates the difference between the current number and its previous \nand checks if the abs of this result < 10^(-8). The sequence gets bigger with \nevery iteration so it will always be bigger than 10^(-8), so the condition will \nalways be false. Even when the numbers become too big and turn into infinity, \nand inf - inf = NaN, here NaN < 10^(-8) will be false, so the condition stays \nfalse and we corr
# ...

# %%
#Ex, 5
def implication(A, B):
     match (A, B):
        case (False, _):    
            return True
        case (True, False):  
            return False
        case (True, True):   
            return True

print('testing implicate function')
x= implication(False,False)
print(f'False && False: {implication(False,False)}')
print(f'False && True: {implication(False,True)}')
print(f'True && False: {implication(True,False)}')
print(f'True && True: {implication(True,True)}')
# Out:
# testing implicate function
# False && False: True
# False && True: True
# True && False: False
# True && True: True

# %%
#Ex. 6
def half_adder(p, q):
    #sum_bits = p ^ q #XOr 
    carry = p & q #And
    sum_or = p | q
    sum_bits = sum_or & (not carry)
    return (sum_bits, carry)

def full_adder(p, q, carry_in):
    sum1, carry_out1 = half_adder(p,q)
    sum2, carry_out2 = half_adder(carry_in, sum1)
    carry_out = carry_out1 | carry_out2
    return (sum2, carry_out)
